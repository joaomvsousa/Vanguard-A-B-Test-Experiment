# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt"
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt"
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt"
url4 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt"

df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)
df4 = pd.read_csv(url4)

# %%
df1.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
duplicate_count = df1['client_id'].nunique()

# %%
duplicate_count
# Out:
# 70609

# %%
df1.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df2.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
df3.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
df4.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
combined_df = pd.concat([df2, df3], axis = 0)

combined_df = combined_df.reset_index(drop=True)

# %%
merge_df = pd.merge(df1, df4, on='client_id', how='inner')

# %%
merge_df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 70604  1411062.68           5.0            5.0       NaN
# 70605   101867.07           6.0            6.0       NaN
# 70606    40745.00           3.0            3.0       NaN
# 70607   475114.69           4.0            4.0       NaN
# 70608   157498.73           7.0            7.0       NaN
#
# [70609 rows x 10 columns]

# %%
test = merge_df.copy()

# %%
test.dropna(subset=["Variation"], inplace=True)

# %%
test.shape
# Out:
# (50500, 10)

# %%
result_2 = pd.merge(test, combined_df, on='client_id', how='left')

# %%
result_2
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0          836976             6.0              73.0      60.5     U
# 1          836976             6.0              73.0      60.5     U
# 2          836976             6.0              73.0      60.5     U
# 3          836976             6.0              73.0      60.5     U
# 4          836976             6.0              73.0      60.5     U
# ...           ...             ...               ...       ...   ...
# 321304    7468138            18.0             222.0      61.0     F
# 321305    7468138            18.0             222.0      61.0     F
# 321306    7468138            18.0             222.0      61.0     F
# 321307    7468138            18.0             222.0      61.0     F
# 321308    7468138            18.0             222.0      61.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth Variation  \
# 0             2.0   45105.30           6.0            9.0      Test
# 1             2.0   45105.30           6.0            9.0      Test
# 2             2.0   45105.30           6.0            9.0      Test
# 3             2.0   45105.30           6.0            9.0      Test
# 4             2.0   45105.30           6.0            9.0      Test
# ...           ...        ...           ...            ...       ...
# 321304        3.0  209278.15           0.0            3.0      Test
# 321305        3.0  209278.15           0.0            3.0      Test
# 321306        3.0  209278.15           0.0            3.0      Test
# 321307        3.0  209278.15           0.0            3.0      Test
# 321308        3.0  209278.15           0.0            3.0      Test
#
#                    visitor_id                      visit_id process_step  \
# 0        427070339_1413275162   228976764_46825473280_96584      confirm
# 1        427070339_1413275162   228976764_46825473280_96584      confirm
# 2        427070339_1413275162   228976764_46825473280_96584      confirm
# 3        427070339_1413275162   228976764_46825473280_96584       step_3
# 4        427070339_1413275162   228976764_46825473280_96584       step_2
# ...                       ...                           ...          ...
# 321304  317123960_46820919455  769876461_30381166055_830233       step_2
# 321305  317123960_46820919455  769876461_30381166055_830233       step_1
# 321306  317123960_46820919455  769876461_30381166055_830233        start
# 321307  317123960_46820919455  769876461_30381166055_830233        start
# 321308  317123960_46820919455  769876461_30381166055_830233        start
#
#                   date_time
# 0       2017-04-02 11:51:13
# 1       2017-04-02 11:47:50
# 2       2017-04-02 11:46:45
# 3       2017-04-02 11:23:08
# 4       2017-04-02 11:22:24
# ...                     ...
# 321304  2017-03-30 23:59:15
# 321305  2017-03-30 23:58:51
# 321306  2017-03-30 23:58:40
# 321307  2017-03-30 23:55:11
# 321308  2017-03-31 00:16:12
#
# [321309 rows x 14 columns]

# %%
result_2.isnull().sum()
# Out:
# client_id             0
# clnt_tenure_yr      102
# clnt_tenure_mnth    102
# clnt_age            114
# gendr               102
# num_accts           102
# bal                 102
# calls_6_mnth        102
# logons_6_mnth       102
# Variation             0
# visitor_id            0
# visit_id              0
# process_step          0
# date_time             0
# dtype: int64

# %%
result_2['clnt_tenure_yr'].fillna(method='bfill', inplace=True)
result_2['clnt_tenure_mnth'].fillna(method='bfill', inplace=True)
result_2['num_accts'].fillna(method='bfill', inplace=True)
result_2['bal'].fillna(method='bfill', inplace=True)
result_2['calls_6_mnth'].fillna(method='bfill', inplace=True)
result_2['logons_6_mnth'].fillna(method='bfill', inplace=True)
result_2['gendr'].fillna(method='bfill', inplace=True)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['clnt_tenure_yr'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['clnt_tenure_yr'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['clnt_tenure_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['clnt_tenure_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['num_accts'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['num_accts'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['bal'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['bal'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['calls_6_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['calls_6_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['logons_6_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['logons_6_mnth'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['gendr'].fillna(method='bfill', inplace=True)
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/517724609.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_2['gendr'].fillna(method='bfill', inplace=True)

# %%
result_2['clnt_age'].fillna((result_2['clnt_age'].mean()), inplace=True)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1582072878.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result_2['clnt_age'].fillna((result_2['clnt_age'].mean()), inplace=True)

# %%
result_2["clnt_age"].min()
# Out:
# 17.0

# %%
age = result_2.copy()

age_no_duplicates = age.drop_duplicates(subset='client_id', keep='first')

# %%
age_no_duplicates["clnt_age"].isnull().sum()
# Out:
# 0

# %%
age_no_duplicates["clnt_age"].unique()
# Out:
# array([60.5       , 58.        , 32.        , 49.        , 33.        ,
#        30.5       , 58.5       , 57.5       , 67.5       , 54.5       ,
#        34.5       , 51.5       , 62.5       , 36.        , 74.        ,
#        32.5       , 31.        , 25.5       , 42.5       , 42.        ,
#        30.        , 55.        , 38.        , 68.5       , 52.5       ,
#        54.        , 63.        , 48.        , 66.5       , 68.        ,
#        65.        , 51.        , 46.        , 63.5       , 23.        ,
#        26.5       , 56.5       , 76.5       , 27.5       , 39.5       ,
#        25.        , 27.        , 60.        , 66.        , 39.        ,
#        56.        , 40.        , 52.        , 31.5       , 43.5       ,
#        35.        , 19.        , 64.5       , 64.        , 22.5       ,
#        33.5       , 36.5       , 61.        , 40.5       , 72.        ,
#        44.5       , 28.5       , 59.5       , 45.        , 18.        ,
#        78.        , 50.5       , 29.        , 37.5       , 57.        ,
#        70.        , 74.5       , 22.        , 50.        , 53.        ,
#        62.        , 65.5       , 29.5       , 28.        , 69.5       ,
#        35.5       , 71.5       , 34.        , 38.5       , 69.        ,
#        43.        , 83.5       , 21.5       , 47.        , 61.5       ,
#        73.5       , 71.        , 59.        , 21.        , 44.        ,
#        83.        , 47.5       , 72.5       , 76.        , 78.5       ,
#        55.5       , 67.        , 41.5       , 20.5       , 75.        ,
#        24.        , 79.        , 26.        , 41.        , 23.5       ,
#        49.5       , 46.5       , 45.5       , 48.5       , 24.5       ,
#        75.5       , 80.        , 73.        , 87.        , 19.5       ,
#        53.5       , 18.5       , 70.5       , 80.5       , 86.        ,
#        37.        , 85.        , 17.5       , 82.        , 20.        ,
#        77.5       , 77.        , 79.5       , 88.5       , 96.        ,
#        81.        , 81.5       , 88.        , 84.        , 48.55351111,
#        94.5       , 89.        , 92.        , 82.5       , 91.5       ,
#        85.5       , 95.5       , 84.5       , 90.        , 89.5       ,
#        93.        , 90.5       , 87.5       , 93.5       , 86.5       ,
#        91.        , 17.        , 94.        , 92.5       ])

# %%
def categorize_age(age):
    if age <= 18:
        return '<18'
    elif 18 < age < 30:
        return '18-29'
    elif 30 <= age < 40:
        return '30-39'
    elif 40 <= age < 50:
        return '40-49'
    elif 50 <= age < 60:
        return '50-59'
    elif 60 <= age < 70:
        return '60-69'
    elif age >= 70:
        return '≥70'

# %%
age_no_duplicates['age_category'] = age_no_duplicates['clnt_age'].apply(categorize_age)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/910922064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_no_duplicates['age_category'] = age_no_duplicates['clnt_age'].apply(categorize_age)

# %%
age_no_duplicates['age_category'].nunique()
# Out:
# 7

# %%
# Calculate the percentage for each age category
age_counts = age_no_duplicates['age_category'].value_counts(normalize=True) * 100

# %%
age_counts
# Out:
# age_category
# 50-59    21.897030
# 30-39    19.154455
# 60-69    18.073267
# 40-49    17.188119
# 18-29    16.625743
# ≥70       6.794059
# <18       0.267327
# Name: proportion, dtype: float64

# %%
# Define the order of age categories
age_order = ['<18', '18-29', '30-39', '40-49', '50-59', '60-69', '≥70']

# Reindex to ensure the correct order
age_percentage_ordered = age_counts.reindex(age_order).fillna(0)

# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=age_percentage_ordered.index, y=age_percentage_ordered.values, palette='viridis')

# Add titles and labels
plt.title('Percentage of Clients by Age')
plt.xlabel('Age Category')
plt.ylabel('Percentage (%)')

# Add percentage labels on top of each bar
for index, value in enumerate(age_percentage_ordered.values):
    plt.text(index, value, f'{value:.1f}%', ha='center', va='bottom')

# Show the plot
plt.show()
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1511457934.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_percentage_ordered.index, y=age_percentage_ordered.values, palette='viridis')

# %%
age_no_duplicates["clnt_tenure_yr"].unique()
# Out:
# array([ 6.,  7.,  5., 16., 12., 30., 15.,  8.,  4.,  3., 10., 11., 13.,
#        14., 19., 18., 25., 23., 21., 17.,  9., 27., 24., 20., 28., 22.,
#        29., 46., 26., 32., 33., 35.,  2., 38., 31., 48., 34., 36., 51.,
#        47., 49., 37., 39., 40., 55., 42., 44., 43., 50., 54., 41., 45.,
#        52.])

# %%
age_no_duplicates["clnt_tenure_yr"].describe()
# Out:
# count    50500.000000
# mean        12.032238
# std          6.860131
# min          2.000000
# 25%          6.000000
# 50%         11.000000
# 75%         16.000000
# max         55.000000
# Name: clnt_tenure_yr, dtype: float64

# %%
def categorize_yr(year):
    if year <= 5:
        return '0-5'
    elif 5 <= year < 15:
        return '5-15'
    elif 15 <= year < 25:
        return '15-25'
    elif 25 <= year < 35:
        return '25-35'
    elif 35 <= year < 45:
        return '35-45'
    elif year >= 45:
        return '45-55'

# %%
age_no_duplicates['year_category'] = age_no_duplicates['clnt_tenure_yr'].apply(categorize_yr)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/2239833442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_no_duplicates['year_category'] = age_no_duplicates['clnt_tenure_yr'].apply(categorize_yr)

# %%
# Calculate the percentage for each year category
year_percentage = age_no_duplicates['year_category'].value_counts(normalize=True) * 100

# Define the order of year categories
year_order = ['0-5', '5-15', '15-25', '25-35', '35-45', '45-55']

# Reindex to ensure the correct order
year_percentage_ordered = year_percentage.reindex(year_order).fillna(0)

# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=year_percentage_ordered.index, y=year_percentage_ordered.values, palette='viridis')

# Add titles and labels
plt.title('Percentage of Clients by Tenure Year Category')
plt.xlabel('Tenure Year Category')
plt.ylabel('Percentage (%)')

# Add percentage labels on top of each bar
for index, value in enumerate(year_percentage_ordered.values):
    plt.text(index, value, f'{value:.1f}%', ha='center', va='bottom')

# Show the plot
plt.show()
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1483648961.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=year_percentage_ordered.index, y=year_percentage_ordered.values, palette='viridis')

# %%
# I want to know the frequency with which the client logged onto Vanguard’s platform over the last six months.
age_no_duplicates["logons_6_mnth"].unique()
# Out:
# array([9., 6., 3., 5., 4., 8., 7.])

# %%
test_data = result_2[result_2['Variation'] == 'Test']
control_data = result_2[result_2['Variation'] == 'Control']

# %%
test_data['date_time'] = pd.to_datetime(test_data['date_time'])
test_data['date'] = pd.to_datetime(test_data['date_time']).dt.date
test_data['time'] = pd.to_datetime(test_data['date_time']).dt.time
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1793364711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['date_time'] = pd.to_datetime(test_data['date_time'])
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1793364711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['date'] = pd.to_datetime(test_data['date_time']).dt.date
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/1793364711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['time'] = pd.to_datetime(test_data['date_time']).dt.time

# %%
test_data
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0          836976             6.0              73.0      60.5     U
# 1          836976             6.0              73.0      60.5     U
# 2          836976             6.0              73.0      60.5     U
# 3          836976             6.0              73.0      60.5     U
# 4          836976             6.0              73.0      60.5     U
# ...           ...             ...               ...       ...   ...
# 321304    7468138            18.0             222.0      61.0     F
# 321305    7468138            18.0             222.0      61.0     F
# 321306    7468138            18.0             222.0      61.0     F
# 321307    7468138            18.0             222.0      61.0     F
# 321308    7468138            18.0             222.0      61.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth Variation  \
# 0             2.0   45105.30           6.0            9.0      Test
# 1             2.0   45105.30           6.0            9.0      Test
# 2             2.0   45105.30           6.0            9.0      Test
# 3             2.0   45105.30           6.0            9.0      Test
# 4             2.0   45105.30           6.0            9.0      Test
# ...           ...        ...           ...            ...       ...
# 321304        3.0  209278.15           0.0            3.0      Test
# 321305        3.0  209278.15           0.0            3.0      Test
# 321306        3.0  209278.15           0.0            3.0      Test
# 321307        3.0  209278.15           0.0            3.0      Test
# 321308        3.0  209278.15           0.0            3.0      Test
#
#                    visitor_id                      visit_id process_step  \
# 0        427070339_1413275162   228976764_46825473280_96584      confirm
# 1        427070339_1413275162   228976764_46825473280_96584      confirm
# 2        427070339_1413275162   228976764_46825473280_96584      confirm
# 3        427070339_1413275162   228976764_46825473280_96584       step_3
# 4        427070339_1413275162   228976764_46825473280_96584       step_2
# ...                       ...                           ...          ...
# 321304  317123960_46820919455  769876461_30381166055_830233       step_2
# 321305  317123960_46820919455  769876461_30381166055_830233       step_1
# 321306  317123960_46820919455  769876461_30381166055_830233        start
# 321307  317123960_46820919455  769876461_30381166055_830233        start
# 321308  317123960_46820919455  769876461_30381166055_830233        start
#
#                  date_time        date      time
# 0      2017-04-02 11:51:13  2017-04-02  11:51:13
# 1      2017-04-02 11:47:50  2017-04-02  11:47:50
# 2      2017-04-02 11:46:45  2017-04-02  11:46:45
# 3      2017-04-02 11:23:08  2017-04-02  11:23:08
# 4      2017-04-02 11:22:24  2017-04-02  11:22:24
# ...                    ...         ...       ...
# 321304 2017-03-30 23:59:15  2017-03-30  23:59:15
# 321305 2017-03-30 23:58:51  2017-03-30  23:58:51
# 321306 2017-03-30 23:58:40  2017-03-30  23:58:40
# 321307 2017-03-30 23:55:11  2017-03-30  23:55:11
# 321308 2017-03-31 00:16:12  2017-03-31  00:16:12
#
# [177847 rows x 16 columns]

# %%
troll_4 = test_data.copy()

# %%
troll_5 = test_data.copy()

# %%
# create a new column for process_step with numbers instead of words
name_to_value = {
    "start": "1",
    "step_1": "2",
    "step_2": "3",
    "step_3": "4",
    "confirm": "5"

}

test_data['process_step_n'] = test_data['process_step'].map(name_to_value)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/2929337590.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['process_step_n'] = test_data['process_step'].map(name_to_value)

# %%
#sorted the data by descending order

test_data.sort_values(by=['client_id',"visit_id", 'process_step_n','date_time'], ascending=False, inplace=True)
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/3626389988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.sort_values(by=['client_id',"visit_id", 'process_step_n','date_time'], ascending=False, inplace=True)

# %%
filtered_data_confirm = test_data[test_data['process_step_n'] == "5"]

# %%
confirm_test_data = filtered_data_confirm.groupby('client_id').first()[["visit_id", 'date_time']]
# Reset index to make 'client_id' a column again
confirm_test_data = confirm_test_data.reset_index()

# %%
confirm_test_data
# Out:
#        client_id                      visit_id           date_time
# 0            555  637149525_38041617439_716659 2017-04-15 13:00:34
# 1            647   40369564_40101682850_311847 2017-04-12 15:47:45
# 2           1336  614001770_19101025926_112779 2017-05-08 08:23:00
# 3           1516  255400977_38039535960_779641 2017-04-06 22:30:18
# 4           1643  753205700_16851596206_134483 2017-06-10 08:00:55
# ...          ...                           ...                 ...
# 18682    9998851  310744937_17135608286_213964 2017-04-05 12:08:43
# 18683    9998964  699981922_52880598802_858635 2017-04-05 23:50:02
# 18684    9999009  149965839_24823291142_245569 2017-03-31 07:20:36
# 18685    9999400  288904166_90826265353_276104 2017-04-20 05:23:27
# 18686    9999729  870243567_56915814033_814203 2017-05-08 16:09:40
#
# [18687 rows x 3 columns]

# %%
total_occurrences_all = len(confirm_test_data)

# %%
filtered_troll = troll_5.drop_duplicates(subset='client_id', inplace = True)

# %%
filtered_troll

# %%
total_occurrences_unique = len( = df.loc[df.index.repeat(df['column_to_duplicate'])]

# %%
confirm_test_data[confirm_test_data["visit_id"] == "529752029_36889679952_99185"]
# Out:
#                               visit_id           date_time
# client_id
# 4436159    529752029_36889679952_99185 2017-04-19 23:10:00
# 9501838    529752029_36889679952_99185 2017-04-19 23:15:59

# %%
test_data[test_data["client_id"] == 1643]
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 171300       1643            19.0             229.0      55.0     M
# 171301       1643            19.0             229.0      55.0     M
# 171302       1643            19.0             229.0      55.0     M
# 171303       1643            19.0             229.0      55.0     M
# 171304       1643            19.0             229.0      55.0     M
# 171298       1643            19.0             229.0      55.0     M
# 171296       1643            19.0             229.0      55.0     M
# 171297       1643            19.0             229.0      55.0     M
# 171299       1643            19.0             229.0      55.0     M
# 171295       1643            19.0             229.0      55.0     M
#
#         num_accts       bal  calls_6_mnth  logons_6_mnth Variation  \
# 171300        2.0  81731.39           0.0            3.0      Test
# 171301        2.0  81731.39           0.0            3.0      Test
# 171302        2.0  81731.39           0.0            3.0      Test
# 171303        2.0  81731.39           0.0            3.0      Test
# 171304        2.0  81731.39           0.0            3.0      Test
# 171298        2.0  81731.39           0.0            3.0      Test
# 171296        2.0  81731.39           0.0            3.0      Test
# 171297        2.0  81731.39           0.0            3.0      Test
# 171299        2.0  81731.39           0.0            3.0      Test
# 171295        2.0  81731.39           0.0            3.0      Test
#
#                    visitor_id                      visit_id process_step  \
# 171300  121807985_20524560478  753205700_16851596206_134483      confirm
# 171301  121807985_20524560478  753205700_16851596206_134483       step_3
# 171302  121807985_20524560478  753205700_16851596206_134483       step_2
# 171303  121807985_20524560478  753205700_16851596206_134483       step_1
# 171304  121807985_20524560478  753205700_16851596206_134483        start
# 171298  910842861_51062379179  633860590_96880450633_976109       step_1
# 171296  910842861_51062379179  633860590_96880450633_976109        start
# 171297  910842861_51062379179  633860590_96880450633_976109        start
# 171299  910842861_51062379179  633860590_96880450633_976109        start
# 171295  910842861_51062379179   379946188_1773022140_107963        start
#
#                  date_time        date      time process_step_n
# 171300 2017-06-10 08:00:55  2017-06-10  08:00:55              5
# 171301 2017-06-10 08:00:25  2017-06-10  08:00:25              4
# 171302 2017-06-10 07:50:43  2017-06-10  07:50:43              3
# 171303 2017-06-10 07:50:27  2017-06-10  07:50:27              2
# 171304 2017-06-10 07:49:27  2017-06-10  07:49:27              1
# 171298 2017-04-24 06:36:32  2017-04-24  06:36:32              2
# 171296 2017-04-24 06:38:20  2017-04-24  06:38:20              1
# 171297 2017-04-24 06:37:17  2017-04-24  06:37:17              1
# 171299 2017-04-24 06:36:07  2017-04-24  06:36:07              1
# 171295 2017-04-15 15:06:00  2017-04-15  15:06:00              1

# %%
filtered_data = troll_4[troll_4['process_step_n'] == "5"]

# %%
first_row_per_visitor = filtered_data.groupby('visitor_id').first()[['date_time']]

# %%
first_row_per_visitor
# Out:
#                                 date_time
# visitor_id
# 100019786_4272121951  2017-04-15 15:16:47
# 100026388_52569174348 2017-06-09 18:41:43
# 100138619_81599280536 2017-06-04 14:28:01
# 100189756_32488226026 2017-05-08 09:29:38
# 100265469_84689631452 2017-04-04 08:15:04
# ...                                   ...
# 999821441_31912441656 2017-04-05 11:13:52
# 999861021_97674299330 2017-04-22 17:00:09
# 999960535_69356103337 2017-04-12 22:09:20
# 999986924_89514756905 2017-05-09 08:17:33
# 999997533_50295491521 2017-04-13 07:41:14
#
# [19505 rows x 1 columns]

# %%
filtered_date.iloc[0]
# Out:
# visitor_id    834634258_21862004160
# date_time       2017-05-08 16:09:40
# Name: 310195, dtype: object

# %%
#filtered_date_df = filtered_date.to_frame()
#filtered_date_df
filtered_date["visitor_id"].nunique()
# Out:
# 19505

# %%
troll_4.sort_values(by=['client_id',"visit_id", 'process_step_n','date_time'], ascending=False, inplace=True)

# %%
df_step_5.drop_duplicates(subset='client_id', "process_step_n", keep='first')
# Out:
#   Cell In[91], line 1
#     df_step_5.drop_duplicates(subset='client_id', "process_step_n", keep='first')
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
troll_4.drop_duplicates(subset=['client_id', 'process_step_n'], keep='first')

# %%
troll_4["process_step_n"].value_counts()

# %%
import matplotlib.pyplot as plt

# Total count of all values
total_count = sum(troll_4["process_step_n"].value_counts())

# Count of value 4
count_4 = troll_4["process_step_n"].value_counts().get(4, 0)

# Percentage of frequency of value 4 against the total
percentage_4 = (count_4 / total_count) * 100

print("Percentage of frequency of value 4 against the total:", percentage_4)

# Pie chart
labels = ['customers', 'confirm']
sizes = [total_count - count_4, count_4]
colors = ['gold', 'lightskyblue']
explode = (0, 0.1)  # explode 2nd slice (value 4)

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Frequency of Values in process_step_n')
plt.show()
# Out:
# Percentage of frequency of value 4 against the total: 14.462993471916871
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_10258/4072165954.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   count_4 = troll_4["process_step_n"].value_counts().get(4, 0)

# %%
def filter_first_step_5_per_client(troll_4):
    # Filter rows where 'process_step_n' is 5
    df_step_5 = troll_4[troll_4['process_step_n'] == "5"]
    
    # Drop duplicates, keeping only the first occurrence for each 'client_id'
    df_first_step_5_per_client = df_step_5.drop_duplicates(subset='client_id', keep='first')
    
    return df_first_step_5_per_client

# Example usage:
# Assuming troll_4 is your DataFrame
filtered_df = filter_first_step_5_per_client(troll_4)

# %%
troll_4.head(20)

# %%
import pandas as pd

def client_process_steps(troll_4):
    # Create a multi-index DataFrame to include both 'date_time' and 'visitor_id'
    troll_4['date_time'] = pd.to_datetime(troll_4['date_time'])
    troll_4_pivot = troll_4.pivot_table(
        index='client_id', 
        columns='process_step_n', 
        values=['date_time', 'visitor_id'], 
        aggfunc='first'
    )

    # Flatten the multi-index columns
    troll_4_pivot.columns = [f'{col[0]}_step_{col[1]}' for col in troll_4_pivot.columns]

    # Reset index to have 'client_id' as a column
    troll_4_pivot.reset_index(inplace=True)

    return troll_4_pivot

# Example usage:
# Assuming your DataFrame is named 'troll_4'
result = client_process_steps(troll_4)
display(result)
# Out:
#        client_id    date_time_step_1    date_time_step_2    date_time_step_3  \
# 0            555 2017-04-15 12:57:56 2017-04-15 12:58:03 2017-04-15 12:58:35
# 1            647 2017-04-12 15:41:28 2017-04-12 15:41:35 2017-04-12 15:41:53
# 2            934 2017-04-18 02:38:52                 NaT                 NaT
# 3           1336 2017-05-08 06:05:12 2017-05-08 06:05:37 2017-05-08 06:06:03
# 4           1346 2017-06-06 18:28:40 2017-06-06 18:23:54 2017-06-06 18:24:01
# ...          ...                 ...                 ...                 ...
# 26963    9999150 2017-05-29 16:55:30 2017-05-29 16:55:18                 NaT
# 26964    9999400 2017-04-20 05:21:28 2017-04-20 05:21:50 2017-04-20 05:22:17
# 26965    9999626 2017-05-14 09:07:51 2017-05-14 09:07:59                 NaT
# 26966    9999729 2017-04-05 13:40:49 2017-04-05 13:41:04 2017-05-08 16:08:40
# 26967    9999832 2017-05-16 16:46:03 2017-05-16 16:46:11                 NaT
#
#          date_time_step_4    date_time_step_5      visitor_id_step_1  \
# 0     2017-04-15 13:00:14 2017-04-15 13:00:34  402506806_56087378777
# 1     2017-04-12 15:45:02 2017-04-12 15:47:45   66758770_53988066587
# 2                     NaT                 NaT  810392784_45004760546
# 3     2017-05-08 06:06:54 2017-05-08 08:23:00  920624746_32603333901
# 4     2017-06-06 18:28:43                 NaT   123474046_4204671056
# ...                   ...                 ...                    ...
# 26963                 NaT                 NaT  665127594_52605538620
# 26964 2017-04-20 05:23:03 2017-04-20 05:23:27  915967319_19082377501
# 26965                 NaT                 NaT   52633065_71189986073
# 26966 2017-05-08 16:09:19 2017-05-08 16:09:40  604429154_69247391147
# 26967                 NaT                 NaT  145538019_54444341400
#
#            visitor_id_step_2      visitor_id_step_3      visitor_id_step_4  \
# 0      402506806_56087378777  402506806_56087378777  402506806_56087378777
# 1       66758770_53988066587   66758770_53988066587   66758770_53988066587
# 2                        NaN                    NaN                    NaN
# 3      920624746_32603333901  920624746_32603333901  920624746_32603333901
# 4       123474046_4204671056   123474046_4204671056   123474046_4204671056
# ...                      ...                    ...                    ...
# 26963  665127594_52605538620                    NaN                    NaN
# 26964  915967319_19082377501  915967319_19082377501  915967319_19082377501
# 26965   52633065_71189986073                    NaN                    NaN
# 26966  604429154_69247391147  834634258_21862004160  834634258_21862004160
# 26967  145538019_54444341400                    NaN                    NaN
#
#            visitor_id_step_5
# 0      402506806_56087378777
# 1       66758770_53988066587
# 2                        NaN
# 3      920624746_32603333901
# 4                        NaN
# ...                      ...
# 26963                    NaN
# 26964  915967319_19082377501
# 26965                    NaN
# 26966  834634258_21862004160
# 26967                    NaN
#
# [26968 rows x 11 columns]

# %% [raw]
# result[result["client_id"] == 555]

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
#create a function

client = troll[troll["visitor_id"] == "966387613_75892747742"]
display(client)
last_time = pd.to_datetime(client[client['process_step']=='confirm'].iloc[0,-3])
first_time = pd.to_datetime(client[client['process_step']=='confirm'].iloc[-1,-3])

delta_total = last_time - first_time
print(f"This user took {round(delta.total_seconds()/60,2)} seconds to complete the whole process")

# %%
#control_data

# %%
test_data.columns = test_data.columns.str.lower()
control_data.columns = control_data.columns.str.lower()

# %%
test_data.isnull().sum()

# %%
test_data.sort_values(["client_id", "visitor_id", "process_step", "date_time" ], ascending=True)

# %%
control_data.sort_values(["client_id", "visitor_id", "process_step", "date_time" ], ascending=True)
